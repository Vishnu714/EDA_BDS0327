# %% [markdown]
# ## Module 2
#
# ### Load the Dataset

# %%
import pandas as pd
df = pd.read_csv("/content/opt.csv")

# %%
df.head(10)
# Out:
#    rownames     PID Clinic Group  Age Black White Nat.Am Asian Hisp  ...  \
# 0         1  100034     NY     C   25   Yes   No     No    No        ...
# 1         2  100042     NY     C   21   Yes   No     No    No        ...
# 2         3  100067     NY     T   25   No    Yes    No    No   Yes  ...
# 3         4  100083     NY     C   36   Yes   No     No    No        ...
# 4         5  100091     NY     C   21   No    Yes    No    No   Yes  ...
# 5         6  100109     NY     T   40   No    No     No    Yes       ...
# 6         7  100117     NY     T   23   Yes   No     No    No        ...
# 7         8  100133     NY     C   28   Yes   No     No    No        ...
# 8         9  100141     NY     T   25   Yes   No     No    No        ...
# 9        10  100158     NY     T   27   Yes   No     No    No        ...
#
#   BL..FN BL..S7 V5..AA V5..PG V5..TD  V5..TF V5..PI  V5..CR V5..FN  V5..S7
# 0    NaN    NaN    NaN    NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 1  22.15  33.02    NaN    NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 2  12.51  23.31    NaN    NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 3    NaN    NaN    NaN    NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 4    NaN    NaN    NaN    NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 5    NaN    NaN    NaN    NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 6    NaN    NaN    NaN    NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 7    NaN    NaN    NaN    NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 8    NaN    NaN    NaN    NaN    NaN     NaN    NaN     NaN    NaN     NaN
# 9  19.68  20.86    NaN    NaN    NaN     NaN    NaN     NaN    NaN     NaN
#
# [10 rows x 172 columns]

# %% [markdown]
# ### explore Dimension, Summary, Data Handling, Data Cleaning,

# %%
#basic information like dimension
print("shape of the dataset")
df.shape
# Out:
# shape of the dataset
# (823, 172)

# %%
#statistical inference
df.describe()
# Out:
#         rownames            PID         Age         BMI  BL.Cig.Day  \
# count  823.00000     823.000000  823.000000  750.000000   92.000000
# mean   412.00000  252541.347509   25.978129   27.669333    8.717391
# std    237.72393  106737.056578    5.565973    7.127299    6.271032
# min      1.00000  100034.000000   16.000000   15.000000    1.000000
# 25%    206.50000  200501.000000   22.000000   23.000000    5.000000
# 50%    412.00000  202717.000000   25.000000   26.000000    7.500000
# 75%    617.50000  302208.000000   30.000000   31.000000   10.000000
# max    823.00000  402477.000000   44.000000   68.000000   30.000000
#
#        BL.Drks.Day  N.prev.preg  N.living.kids     Tx.time  N.extractions  \
# count    13.000000   606.000000     522.000000  395.000000     447.000000
# mean      4.461538     2.462046       1.955939    2.185696       0.919463
# std       9.386297     1.719421       1.237596    0.974737       1.538082
# min       0.000000     1.000000       0.000000    0.116667       0.000000
# 25%       0.000000     1.000000       1.000000    1.416667       0.000000
# 50%       1.000000     2.000000       2.000000    2.166667       0.000000
# 75%       5.000000     3.000000       2.000000    2.750000       1.000000
# max      35.000000    11.000000       9.000000    5.833333      20.000000
#
#        ...      BL..FN      BL..S7      V5..AA      V5..PG      V5..TD  \
# count  ...  393.000000  393.000000  325.000000  325.000000  325.000000
# mean   ...   18.188957   35.297888    0.263692    3.522800    1.471815
# std    ...    9.478268   14.696960    1.123674    7.727432    2.292366
# min    ...    0.330000    0.420000    0.000000    0.000000    0.000000
# 25%    ...   12.070000   25.130000    0.000000    0.000000    0.030000
# 50%    ...   17.370000   34.470000    0.000000    0.020000    0.700000
# 75%    ...   23.030000   43.980000    0.080000    3.400000    1.960000
# max    ...   63.200000   86.340000   16.100000   59.710000   20.490000
#
#            V5..TF      V5..PI      V5..CR      V5..FN      V5..S7
# count  325.000000  325.000000  325.000000  325.000000  325.000000
# mean     2.923292    2.767077    1.664892   16.857508   29.471200
# std      3.097833    5.167062    2.270171    8.545836   14.660155
# min      0.000000    0.000000    0.000000    0.000000    2.560000
# 25%      0.510000    0.000000    0.410000   10.930000   18.510000
# 50%      2.020000    0.070000    0.960000   15.360000   28.190000
# 75%      4.130000    3.410000    1.920000   21.530000   38.540000
# max     19.310000   40.730000   14.640000   49.880000   80.850000
#
# [8 rows x 99 columns]

# %% [markdown]
# ### insights from the dataset
# ###- there is diffence in count of values in each column,
# ### suggests there are insufficient data.
# ### and there are columns with no value
# ### solution: Data Handling

# %%
# Checking for null values in each column
df.isnull().sum()
# Out:
# rownames      0
# PID           0
# Clinic        0
# Group         0
# Age           0
#            ...
# V5..TF      498
# V5..PI      498
# V5..CR      498
# V5..FN      498
# V5..S7      498
# Length: 172, dtype: int64

# %%
#NaN values in pandas objects
df.isnull()
# Out:
#      rownames    PID  Clinic  Group    Age  Black  White  Nat.Am  Asian  \
# 0       False  False   False  False  False  False  False   False  False
# 1       False  False   False  False  False  False  False   False  False
# 2       False  False   False  False  False  False  False   False  False
# 3       False  False   False  False  False  False  False   False  False
# 4       False  False   False  False  False  False  False   False  False
# ..        ...    ...     ...    ...    ...    ...    ...     ...    ...
# 818     False  False   False  False  False  False  False   False  False
# 819     False  False   False  False  False  False  False   False  False
# 820     False  False   False  False  False  False  False   False  False
# 821     False  False   False  False  False  False  False   False  False
# 822     False  False   False  False  False  False  False   False  False
#
#       Hisp  ...  BL..FN  BL..S7  V5..AA  V5..PG  V5..TD  V5..TF  V5..PI  \
# 0    False  ...    True    True    True    True    True    True    True
# 1    False  ...   False   False    True    True    True    True    True
# 2    False  ...   False   False    True    True    True    True    True
# 3    False  ...    True    True    True    True    True    True    True
# 4    False  ...    True    True    True    True    True    True    True
# ..     ...  ...     ...     ...     ...     ...     ...     ...     ...
# 818  False  ...    True    True    True    True    True    True    True
# 819  False  ...    True    True    True    True    True    True    True
# 820  False  ...   False   False   False   False   False   False   False
# 821  False  ...    True    True    True    True    True    True    True
# 822  False  ...    True    True    True    True    True    True    True
#
#      V5..CR  V5..FN  V5..S7
# 0      True    True    True
# 1      True    True    True
# 2      True    True    True
# 3      True    True    True
# 4      True    True    True
# ..      ...     ...     ...
# 818    True    True    True
# 819    True    True    True
# 820   False   False   False
# 821    True    True    True
# 822    True    True    True
#
# [823 rows x 172 columns]

# %%
# Identifying completely empty columns
df.columns[df.isnull().any()].tolist()
# Out:
# ['BL.Diab.Type',
#  'BMI',
#  'BL.Cig.Day',
#  'BL.Drks.Day',
#  'N.prev.preg',
#  'Live.PTB',
#  'Any.stillbirth',
#  'Spont.ab',
#  'Induced.ab',
#  'Any.live.ptb.sb.sp.ab.in.ab',
#  'N.living.kids',
#  'Tx.comp.',
#  'Local.anes',
#  'Topical.Anest',
#  'Tx.time',
#  'Completed.EDC',
#  'N.extractions',
#  'N.perm.restorations',
#  'V3.GE',
#  'V3..BOP',
#  'V3.PD.avg',
#  'V3..PD.4',
#  'V3..PD.5',
#  'V3.CAL.avg',
#  'V3..CAL.2',
#  'V3..CAL.3',
#  'V3.Calc.I',
#  'V3.Pl.I',
#  'V5.GE',
#  'V5..BOP',
#  'V5.PD.avg',
#  'V5..PD.4',
#  'V5..PD.5',
#  'V5.CAL.avg',
#  'V5..CAL.2',
#  'V5..CAL.3',
#  'V5.Calc.I',
#  'V5.Pl.I',
#  'N.PAL.sites',
#  'Birthweight',
#  'Apgar1',
#  'Apgar5',
#  'V3.Anti.inf',
#  'V3.Cortico',
#  'V3.Antibio',
#  'V3.Bac.vag',
#  'V5.Anti.inf',
#  'V5.Cortico',
#  'V5.Antibio',
#  'V5.Bac.vag',
#  'BL.DNA',
#  'BL.Univ',
#  'BL.AA',
#  'BL.PG',
#  'BL.TD',
#  'BL.TF',
#  'BL.PI',
#  'BL.CR',
#  'BL.FN',
#  'BL.S7',
#  'V5.DNA',
#  'V5.Univ',
#  'V5.AA',
#  'V5.PG',
#  'V5.TD',
#  'V5.TF',
#  'V5.PI',
#  'V5.CR',
#  'V5.FN',
#  'V5.S7',
#  'BL..AA',
#  'BL..PG',
#  'BL..TD',
#  'BL..TF',
#  'BL..PI',
#  'BL..CR',
#  'BL..FN',
#  'BL..S7',
#  'V5..AA',
#  'V5..PG',
#  'V5..TD',
#  'V5..TF',
#  'V5..PI',
#  'V5..CR',
#  'V5..FN',
#  'V5..S7']

# %%
# total number of missing values
df.isnull().sum().sum()
# Out:
# np.int64(28285)

# %%
# if the values int column is null more than 90% we drop those columns
threshold = 0.9* len(df)
df_cleaned = df.dropna(axis=1, thresh=threshold)

# %%
df_cleaned.head(10)
# Out:
#    rownames     PID Clinic Group  Age Black White Nat.Am Asian Hisp  ...  \
# 0         1  100034     NY     C   25   Yes   No     No    No        ...
# 1         2  100042     NY     C   21   Yes   No     No    No        ...
# 2         3  100067     NY     T   25   No    Yes    No    No   Yes  ...
# 3         4  100083     NY     C   36   Yes   No     No    No        ...
# 4         5  100091     NY     C   21   No    Yes    No    No   Yes  ...
# 5         6  100109     NY     T   40   No    No     No    Yes       ...
# 6         7  100117     NY     T   23   Yes   No     No    No        ...
# 7         8  100133     NY     C   28   Yes   No     No    No        ...
# 8         9  100141     NY     T   25   Yes   No     No    No        ...
# 9        10  100158     NY     T   27   Yes   No     No    No        ...
#
#     OTF5  OCRP5 O1B5  O65  O85   OPGE25 OTNF5 OMMP95 ETXU_CAT5 OFIBRIN5
# 0   7.27  7.012  1.2  4.9  1.2   836.57   1.2  1.126         1     58.4
# 1      .      .    .    .    .        .     .      .         .        .
# 2      .      .    .    .    .        .     .      .         .        .
# 3  5.691  7.848  1.2  4.9  1.2   252.26   1.2  0.428         1       76
# 4  2.831   2.76  1.2  4.9  1.2  1521.16   1.2  0.236         1       78
# 5      .      .    .    .    .        .     .      .         .        .
# 6  7.402  4.512  1.2  4.9  1.2   492.46   1.2    0.2         1       38
# 7      .      .    .    .    .        .     .      .         .        .
# 8  4.346  2.428  1.2  4.9  1.2  1209.03   1.2  0.363         1     46.8
# 9      .      .    .    .    .        .     .      .         .        .
#
# [10 rows x 91 columns]

# %%
# Checking for null values in each column in cleaned dataset
df_cleaned.isnull().sum().sum()
# Out:
# np.int64(171)

# %%
# Getting data types of all columns
df_cleaned.dtypes
# Out:
# rownames      int64
# PID           int64
# Clinic       object
# Group        object
# Age           int64
#               ...
# OPGE25       object
# OTNF5        object
# OMMP95       object
# ETXU_CAT5    object
# OFIBRIN5     object
# Length: 91, dtype: object

# %%
# Dropping column name :rownames
df_cleaned = df_cleaned.drop('rownames', axis=1)
df_cleaned.head(10)
# Out:
#       PID Clinic Group  Age Black White Nat.Am Asian Hisp  Education  ...  \
# 0  100034     NY     C   25   Yes   No     No    No        8-12 yrs   ...
# 1  100042     NY     C   21   Yes   No     No    No        8-12 yrs   ...
# 2  100067     NY     T   25   No    Yes    No    No   Yes  8-12 yrs   ...
# 3  100083     NY     C   36   Yes   No     No    No        MT 12 yrs  ...
# 4  100091     NY     C   21   No    Yes    No    No   Yes  8-12 yrs   ...
# 5  100109     NY     T   40   No    No     No    Yes       8-12 yrs   ...
# 6  100117     NY     T   23   Yes   No     No    No        8-12 yrs   ...
# 7  100133     NY     C   28   Yes   No     No    No        LT 8 yrs   ...
# 8  100141     NY     T   25   Yes   No     No    No        8-12 yrs   ...
# 9  100158     NY     T   27   Yes   No     No    No        MT 12 yrs  ...
#
#     OTF5  OCRP5 O1B5  O65  O85   OPGE25 OTNF5 OMMP95 ETXU_CAT5  OFIBRIN5
# 0   7.27  7.012  1.2  4.9  1.2   836.57   1.2  1.126         1      58.4
# 1      .      .    .    .    .        .     .      .         .         .
# 2      .      .    .    .    .        .     .      .         .         .
# 3  5.691  7.848  1.2  4.9  1.2   252.26   1.2  0.428         1        76
# 4  2.831   2.76  1.2  4.9  1.2  1521.16   1.2  0.236         1        78
# 5      .      .    .    .    .        .     .      .         .         .
# 6  7.402  4.512  1.2  4.9  1.2   492.46   1.2    0.2         1        38
# 7      .      .    .    .    .        .     .      .         .         .
# 8  4.346  2.428  1.2  4.9  1.2  1209.03   1.2  0.363         1      46.8
# 9      .      .    .    .    .        .     .      .         .         .
#
# [10 rows x 90 columns]

# %%
# In the dataset there is a column with aplhanumeric
df_cleaned['Education'].value_counts()
# Out:
# Education
# 8-12 yrs     479
# MT 12 yrs    190
# LT 8 yrs     154
# Name: count, dtype: int64

# %%
df_cleaned['Group'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Splitting the dataframe by numerical and object datatype
# ### - makes working with the dataset easier
# ### - number of columns are too huge to view
# ### - splitting the dataframes makes the process easier

# %%
# Insights some columns have numerical data i.e (int64, float64)
numeric_df = df_cleaned.select_dtypes(include='number')
numeric_df.head(10)
# Out:
#       PID  Age   BMI  N.qualifying.teeth  BL.GE  BL..BOP  BL.PD.avg  BL..PD.4  \
# 0  100034   25   NaN                  13  1.429   48.214      2.696    17.857
# 1  100042   21  21.0                  12  1.298   79.762      2.685    17.857
# 2  100067   25  24.0                  16  1.784   80.247      2.821    25.309
# 3  100083   36  36.0                  15  1.596  100.000      2.814    17.308
# 4  100091   21  27.0                  16  1.173   94.048      2.768    23.214
# 5  100109   40  24.0                  16  0.969   85.185      2.932    25.309
# 6  100117   23  32.0                  19  1.857   92.262      2.738    20.833
# 7  100133   28   NaN                  10  1.621   64.000      2.813    17.333
# 8  100141   25  26.0                  21  1.981   94.444      2.994    29.012
# 9  100158   27  28.0                  11  1.193   92.000      2.793    18.000
#
#    BL..PD.5  BL.CAL.avg  ...  Apgar1  Apgar5  GA...1st.SAE  BL.Anti.inf  \
# 0     5.357       1.291  ...     9.0     9.0           259            0
# 1    10.119       1.119  ...     4.0     7.0           259            0
# 2    12.346       1.407  ...     8.0     9.0           259            0
# 3     5.769       1.494  ...     9.0     9.0           259            1
# 4    14.286       1.327  ...     9.0     9.0           259            0
# 5    10.494       1.432  ...     8.0     9.0           259            0
# 6     5.357       1.292  ...     8.0     9.0           259            0
# 7     8.667       1.407  ...     9.0     9.0           259            0
# 8     7.407       1.611  ...     9.0     9.0           259            0
# 9     8.667       1.439  ...     NaN     NaN           150            0
#
#    BL.Cortico  BL.Antibio  BL.Bac.vag  X..Vis.Att  X..Vis.Elig  X1st.Miss.Vis
# 0           0           0           0           5            5            100
# 1           0           0           0           0            5              2
# 2           0           0           0           2            5              3
# 3           0           0           0           3            5              2
# 4           0           0           0           4            5              5
# 5           0           0           0           1            5              3
# 6           0           0           0           4            5              6
# 7           0           0           0           2            5              3
# 8           0           0           0           4            5              4
# 9           0           0           0           1            1            100
#
# [10 rows x 27 columns]

# %% [markdown]
# ### Taking care of columns with numeric dataset handling missing values

# %%
# First check for missing Values
na_cnt=numeric_df.isna().sum()
na_cnt.sum()
# Out:
# np.int64(171)

# %%
# Filling all the null values of the numeical columns
na_counts = numeric_df.isna().sum()

# Filter columns with any NA values
na_counts = na_counts[na_counts > 0]
na_counts
# Out:
# BMI            73
# N.PAL.sites     2
# Birthweight    14
# Apgar1         41
# Apgar5         41
# dtype: int64

# %%
# we can use mean imputation, bfill and ffill to these columns

mean_impute_columns = ['BMI', 'Birthweight']
bfill_columns = ['N.PAL.sites', 'Apgar5']
ffill_columns = ['Apgar1']

# Mean imputation
numeric_df[mean_impute_columns] = numeric_df[mean_impute_columns].apply(lambda col: col.fillna(col.mean()))

# Backward fill
numeric_df[bfill_columns] = numeric_df[bfill_columns].apply(lambda col: col.fillna(method='bfill'))

# Forward fill
numeric_df[ffill_columns] =numeric_df[ffill_columns].apply(lambda col: col.fillna(method='ffill'))
# Out:
# <ipython-input-22-faba12d8ea36>:11: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   numeric_df[bfill_columns] = numeric_df[bfill_columns].apply(lambda col: col.fillna(method='bfill'))
# <ipython-input-22-faba12d8ea36>:14: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   numeric_df[ffill_columns] =numeric_df[ffill_columns].apply(lambda col: col.fillna(method='ffill'))

# %%
# Null values in numeric_df handled
numeric_df.isna().sum().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Taking care of columns with numeric dataset handling missing values

# %%
# Identifying columns with object type
object_df = df.select_dtypes(include='object')
object_df.head(10)
# Out:
#   Clinic Group Black White Nat.Am Asian Hisp  Education Public.Asstce  \
# 0     NY     C   Yes   No     No    No        8-12 yrs            No
# 1     NY     C   Yes   No     No    No        8-12 yrs            Yes
# 2     NY     T   No    Yes    No    No   Yes  8-12 yrs            No
# 3     NY     C   Yes   No     No    No        MT 12 yrs           Yes
# 4     NY     C   No    Yes    No    No   Yes  8-12 yrs            No
# 5     NY     T   No    No     No    Yes       8-12 yrs            No
# 6     NY     T   Yes   No     No    No        8-12 yrs            Yes
# 7     NY     C   Yes   No     No    No        LT 8 yrs            No
# 8     NY     T   Yes   No     No    No        8-12 yrs            No
# 9     NY     T   Yes   No     No    No        MT 12 yrs           No
#
#   Hypertension  ...   OTF5  OCRP5 O1B5  O65  O85   OPGE25 OTNF5 OMMP95  \
# 0          N    ...   7.27  7.012  1.2  4.9  1.2   836.57   1.2  1.126
# 1          N    ...      .      .    .    .    .        .     .      .
# 2          N    ...      .      .    .    .    .        .     .      .
# 3          N    ...  5.691  7.848  1.2  4.9  1.2   252.26   1.2  0.428
# 4          N    ...  2.831   2.76  1.2  4.9  1.2  1521.16   1.2  0.236
# 5          N    ...      .      .    .    .    .        .     .      .
# 6          N    ...  7.402  4.512  1.2  4.9  1.2   492.46   1.2    0.2
# 7          N    ...      .      .    .    .    .        .     .      .
# 8          N    ...  4.346  2.428  1.2  4.9  1.2  1209.03   1.2  0.363
# 9          N    ...      .      .    .    .    .        .     .      .
#
#   ETXU_CAT5 OFIBRIN5
# 0         1     58.4
# 1         .        .
# 2         .        .
# 3         1       76
# 4         1       78
# 5         .        .
# 6         1       38
# 7         .        .
# 8         1     46.8
# 9         .        .
#
# [10 rows x 73 columns]

# %%
object_df['Hisp'].value_counts()
# there are 145 empty values
# Out:
# Hisp
# Yes    350
# No     328
#        145
# Name: count, dtype: int64

# %%
# Filling all the null values of the numeical columnsna_counts = object_df.isna().sum()
na_counts = object_df.isna().sum()

na_counts = na_counts[na_counts > 0]
na_counts
# Out:
# BL.Diab.Type                   799
# Live.PTB                       212
# Any.stillbirth                 212
# Spont.ab                       212
# Induced.ab                     212
# Any.live.ptb.sb.sp.ab.in.ab    212
# Tx.comp.                       410
# Local.anes                     410
# Topical.Anest                  410
# Completed.EDC                  318
# dtype: int64

# %%
# BL.Diab.Type column has the highest null count drop it
objedct_df = object_df.drop(columns=['BL.Diab.Type'])

# %%
object_df.head(10)
# Out:
#   Clinic Group Black White Nat.Am Asian Hisp  Education Public.Asstce  \
# 0     NY     C   Yes   No     No    No        8-12 yrs            No
# 1     NY     C   Yes   No     No    No        8-12 yrs            Yes
# 2     NY     T   No    Yes    No    No   Yes  8-12 yrs            No
# 3     NY     C   Yes   No     No    No        MT 12 yrs           Yes
# 4     NY     C   No    Yes    No    No   Yes  8-12 yrs            No
# 5     NY     T   No    No     No    Yes       8-12 yrs            No
# 6     NY     T   Yes   No     No    No        8-12 yrs            Yes
# 7     NY     C   Yes   No     No    No        LT 8 yrs            No
# 8     NY     T   Yes   No     No    No        8-12 yrs            No
# 9     NY     T   Yes   No     No    No        MT 12 yrs           No
#
#   Hypertension  ...   OTF5  OCRP5 O1B5  O65  O85   OPGE25 OTNF5 OMMP95  \
# 0          N    ...   7.27  7.012  1.2  4.9  1.2   836.57   1.2  1.126
# 1          N    ...      .      .    .    .    .        .     .      .
# 2          N    ...      .      .    .    .    .        .     .      .
# 3          N    ...  5.691  7.848  1.2  4.9  1.2   252.26   1.2  0.428
# 4          N    ...  2.831   2.76  1.2  4.9  1.2  1521.16   1.2  0.236
# 5          N    ...      .      .    .    .    .        .     .      .
# 6          N    ...  7.402  4.512  1.2  4.9  1.2   492.46   1.2    0.2
# 7          N    ...      .      .    .    .    .        .     .      .
# 8          N    ...  4.346  2.428  1.2  4.9  1.2  1209.03   1.2  0.363
# 9          N    ...      .      .    .    .    .        .     .      .
#
#   ETXU_CAT5 OFIBRIN5
# 0         1     58.4
# 1         .        .
# 2         .        .
# 3         1       76
# 4         1       78
# 5         .        .
# 6         1       38
# 7         .        .
# 8         1     46.8
# 9         .        .
#
# [10 rows x 73 columns]

# %%
threshold = 0.9* len(df)
object_df= object_df.dropna(axis=1, thresh=threshold)

# %%
object_df.isna().sum().sum()
# the object_df dataframe null values have been removed
# Out:
# np.int64(0)

# %%
object_df['OTF5'].value_counts()
# Out:
# OTF5
# .         188
# 9.133       2
# 3.18        2
# 2.656       2
# 6.424       2
#          ...
# 10.706      1
# 7.893       1
# 4.835       1
# 4.791       1
# 12.206      1
# Name: count, Length: 615, dtype: int64

# %%
object_columns = object_df.columns
object_columns
# Out:
# Index(['Clinic', 'Group', 'Black', 'White', 'Nat.Am', 'Asian', 'Hisp',
#        'Education', 'Public.Asstce', 'Hypertension', 'Diabetes', 'Use.Tob',
#        'Use.Alc', 'Drug.Add', 'Prev.preg', 'EDC.necessary.', 'Birth.outcome',
#        'Preg.ended...37.wk', 'Fetal.congenital.anomaly', 'Any.SAE.',
#        'Bact.vag', 'Gest.diab', 'Oligo', 'Polyhyd', 'Gonorrhea', 'Chlamydia',
#        'Strep.B', 'Traumatic.Inj', 'UTI', 'Pre.eclamp', 'Mom.HIV.status',
#        'OAA1', 'OCR1', 'OFN1', 'OPG1', 'OPI1', 'OTD1', 'OTF1', 'OCRP1', 'O1B1',
#        'O61', 'O81', 'OPGE21', 'OTNF1', 'OMMP91', 'ETXU_CAT1', 'OFIBRIN1',
#        'OAA5', 'OCR5', 'OFN5', 'OPG5', 'OPI5', 'OTD5', 'OTF5', 'OCRP5', 'O1B5',
#        'O65', 'O85', 'OPGE25', 'OTNF5', 'OMMP95', 'ETXU_CAT5', 'OFIBRIN5'],
#       dtype='object')

# %%
# Index of the column that has numeric data type but is in object data type
object_df.columns.get_loc('OAA1')
# Out:
# 31

# %%
# Converting
columns = object_df.columns[31:]

for column in columns:

    object_df[column] = object_df[column].replace({'.': pd.NA, '': pd.NA})


    object_df[column] = pd.to_numeric(object_df[column], errors='coerce')

# %%
object_df[columns]
# Out:
#        OAA1    OCR1    OFN1    OPG1   OPI1   OTD1    OTF1   OCRP1  O1B1  \
# 0     6.745   5.476   3.816  16.720  3.599  5.909   7.056  18.331   1.2
# 1    13.281   4.597   3.525   3.894  2.677  5.408   6.388   6.929   1.2
# 2    16.170   6.077   4.462  16.164  2.985  5.803   5.893   2.813   1.2
# 3     8.795   8.197   4.847  18.257  9.439  3.975   4.847  31.500   1.2
.isna().sum().sum()
# Out:
# np.int64(0)

# %%
# Done with Data handling
data=merged_df.head()

# %% [markdown]
# ##Module3
#
# ### Univariate, Bivariate and Multivariate Analysis (all the possibilities of visualizations).

# %% [markdown]
# ## Univariate

# %%
# Describe
data.describe()
# Out:
#                 PID        Age        BMI  N.qualifying.teeth     BL.GE  \
# count       5.00000   5.000000   5.000000            5.000000  5.000000
# mean   100093.20000  26.000000  29.733867           16.800000  1.607200
# std        40.20199   5.830952   4.185626            3.193744  0.325014
# min    100034.00000  21.000000  26.000000           13.000000  1.173000
# 25%    100083.00000  23.000000  27.000000           15.000000  1.429000
# 50%    100091.00000  25.000000  27.669333           16.000000  1.596000
# 75%    100117.00000  25.000000  32.000000           19.000000  1.857000
# max    100141.00000  36.000000  36.000000           21.000000  1.981000
#
#           BL..BOP  BL.PD.avg   BL..PD.4   BL..PD.5  BL.CAL.avg  ...      OTF5  \
# count    5.000000   5.000000   5.000000   5.000000    5.000000  ...  5.000000
# mean    85.793600   2.802000  21.644800   7.635200    1.403000  ...  5.508000
# std     21.206443   0.115646   4.757949   3.812752    0.143341  ...  1.952046
# min     48.214000   2.696000  17.308000   5.357000    1.291000  ...  2.831000
# 25%     92.262000   2.738000  17.857000   5.357000    1.292000  ...  4.346000
# 50%     94.048000   2.768000  20.833000   5.769000    1.327000  ...  5.691000
# 75%     94.444000   2.814000  23.214000   7.407000    1.494000  ...  7.270000
# max    100.000000   2.994000  29.012000  14.286000    1.611000  ...  7.402000
#
#           OCRP5  O1B5  O65  O85       OPGE25  OTNF5   OMMP95  ETXU_CAT5  \
# count  5.000000   5.0  5.0  5.0     5.000000    5.0  5.00000        5.0
# mean   4.912000   1.2  4.9  1.2   862.296000    1.2  0.47060        1.0
# std    2.449054   0.0  0.0  0.0   515.730223    0.0  0.37789        0.0
# min    2.428000   1.2  4.9  1.2   252.260000    1.2  0.20000        1.0
# 25%    2.760000   1.2  4.9  1.2   492.460000    1.2  0.23600        1.0
# 50%    4.512000   1.2  4.9  1.2   836.570000    1.2  0.36300        1.0
# 75%    7.012000   1.2  4.9  1.2  1209.030000    1.2  0.42800        1.0
# max    7.848000   1.2  4.9  1.2  1521.160000    1.2  1.12600        1.0
#
#         OFIBRIN5
# count   5.000000
# mean   59.440000
# std    17.601364
# min    38.000000
# 25%    46.800000
# 50%    58.400000
# 75%    76.000000
# max    78.000000
#
# [8 rows x 59 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
# Bar plot for Age

plt.figure(figsize=(18, 5))
sns.barplot(x=df.index, y='Age', data=df, color='skyblue')
plt.title('Bar Graph: Age')
# Out:
# Text(0.5, 1.0, 'Bar Graph: Age')

# %%
# Distribution plot of BMI

plt.figure(figsize=(18, 5))
sns.histplot(df['BMI'], kde=True, color='lightgreen', bins=6)
plt.title('Distribution Plot: BMI')
# Out:
# Text(0.5, 1.0, 'Distribution Plot: BMI')

# %%
# Box plot
plt.figure(figsize=(18, 5))
sns.boxplot(x=df['N.qualifying.teeth'], color='lightcoral')
plt.title('Box Plot: N.qualifying.teeth')
# Out:
# Text(0.5, 1.0, 'Box Plot: N.qualifying.teeth')

# %% [markdown]
# ## Univariate analysis of multiple columns

# %%
data[columns].hist(bins=30, figsize=(15, 10), edgecolor='black')
plt.suptitle("Univariate Analysis - Histograms")
plt.show()

# %% [markdown]
# ## Bivariate Analysis

# %%
# Box plot for Age and BMI
sns.boxplot(x="Age",y="BMI",data=data)
plt.show()

# %%
# box plot on N.qualifying.teeth	vs Birthweight

sns.boxplot(x="N.qualifying.teeth", y="Birthweight",data=data)
plt.show()

# %%
# Scatter plot 'BMI', 'Birthweight'

plt.scatter(data["BMI"], data["Birthweight"])
plt.title("Scatter Plot for horsepower vs price")
plt.xlabel("horsepower")
plt.ylabel("price")
# Out:
# Text(0, 0.5, 'price')

# %% [markdown]
# # Multivariate Analysis

# %%
sns.pairplot(df,vars = ['BMI', 'Age','Birthweight'], kind="reg")
plt.show()

# %%
numeric_df.columns
# Out:
# Index(['PID', 'Age', 'BMI', 'N.qualifying.teeth', 'BL.GE', 'BL..BOP',
#        'BL.PD.avg', 'BL..PD.4', 'BL..PD.5', 'BL.CAL.avg', 'BL..CAL.2',
#        'BL..CAL.3', 'BL.Calc.I', 'BL.Pl.I', 'N.PAL.sites', 'GA.at.outcome',
#        'Birthweight', 'Apgar1', 'Apgar5', 'GA...1st.SAE', 'BL.Anti.inf',
#        'BL.Cortico', 'BL.Antibio', 'BL.Bac.vag', 'X..Vis.Att', 'X..Vis.Elig',
#        'X1st.Miss.Vis'],
#       dtype='object')

# %%
object_df.columns
# Out:
# Index(['Clinic', 'Group', 'Black', 'White', 'Nat.Am', 'Asian', 'Hisp',
#        'Education', 'Public.Asstce', 'Hypertension', 'Diabetes', 'Use.Tob',
#        'Use.Alc', 'Drug.Add', 'Prev.preg', 'EDC.necessary.', 'Birth.outcome',
#        'Preg.ended...37.wk', 'Fetal.congenital.anomaly', 'Any.SAE.',
#        'Bact.vag', 'Gest.diab', 'Oligo', 'Polyhyd', 'Gonorrhea', 'Chlamydia',
#        'Strep.B', 'Traumatic.Inj', 'UTI', 'Pre.eclamp', 'Mom.HIV.status',
#        'OAA1', 'OCR1', 'OFN1', 'OPG1', 'OPI1', 'OTD1', 'OTF1', 'OCRP1', 'O1B1',
#        'O61', 'O81', 'OPGE21', 'OTNF1', 'OMMP91', 'ETXU_CAT1', 'OFIBRIN1',
#        'OAA5', 'OCR5', 'OFN5', 'OPG5', 'OPI5', 'OTD5', 'OTF5', 'OCRP5', 'O1B5',
#        'O65', 'O85', 'OPGE25', 'OTNF5', 'OMMP95', 'ETXU_CAT5', 'OFIBRIN5'],
#       dtype='object')

# %%
sns.set(style="ticks", color_codes=True)
sns.pairplot(df,height=2,vars = ['N.qualifying.teeth', 'Apgar1','Apgar5'], hue="Group")
plt.show()

# %%
from scipy import stats

corr = stats.pearsonr(data["X..Vis.Att"], data["X..Vis.Elig"])
print("p-value:\t", corr[1])
print("cor:\t\t", corr[0])
# Out:
# p-value:	 nan
# cor:		 nan
# <ipython-input-56-036ac2609168>:3: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   corr = stats.pearsonr(data["X..Vis.Att"], data["X..Vis.Elig"])

# %% [markdown]
# ## Correlation Matrix of the Numerical data

# %%
# To find the correlation among the entire numerical records
# the columns using pearson method
correlation = numeric_df.corr(method='pearson', numeric_only=True)
correlation
# Out:
#                          PID       Age       BMI  N.qualifying.teeth  \
# PID                 1.000000 -0.153566  0.130601           -0.005121
# Age                -0.153566  1.000000  0.123381            0.116968
# BMI                 0.130601  0.123381  1.000000            0.039364
# N.qualifying.teeth -0.005121  0.116968  0.039364            1.000000
# GA.at.outcome          0.049074    0.004390    0.056541    0.039984
# Birthweight            0.111002    0.044379    0.016486    0.057879
# Apgar1                -0.012395   -0.020686    0.007825   -0.012516
# Apgar5                 0.011352   -0.005657    0.025616    0.005898
# GA...1st.SAE           0.020909    0.014928    0.042247   -0.004960
# BL.Anti.inf            1.000000    0.019406    0.166726    0.156304
# BL.Cortico             0.019406    1.000000   -0.021141    0.074771
# BL.Antibio             0.166726   -0.021141    1.000000    0.139295
# BL.Bac.vag             0.156304    0.074771    0.139295    1.000000
# X..Vis.Att             0.032839   -0.000574    0.072615    0.014868
# X..Vis.Elig            0.074403    0.014132    0.040325    0.011880
# X1st.Miss.Vis          0.013873    0.033322    0.035705   -0.009700
#
#                     X..Vis.Att  X..Vis.Elig  X1st.Miss.Vis
# PID                   0.087704    -0.026448       0.151489
# Age                   0.028524    -0.010835      -0.014227
# BMI                  -0.094123    -0.061293      -0.097934
# N.qualifying.teeth   -0.010131     0.010852      -0.064770
# BL.GE                -0.193386     0.057353      -0.237558
# BL..BOP              -0.117944    -0.002897      -0.148165
# BL.PD.avg            -0.033006     0.053723      -0.076015
# BL..PD.4             -0.002708     0.049634      -0.058127
# BL..PD.5             -0.011541     0.050353      -0.069710
# BL.CAL.avg           -0.132411    -0.038171      -0.132138
# BL..CAL.2            -0.129960    -0.041533      -0.124325
# BL..CAL.3            -0.088535    -0.034216      -0.092693
# BL.Calc.I            -0.025918     0.065506      -0.085492
# BL.Pl.I              -0.132444     0.016623      -0.172292
# N.PAL.sites           0.062173     0.036106       0.021496
# GA.at.outcome         0.392075     0.739577       0.087660
# Birthweight           0.279060     0.580918       0.099769
# Apgar1                0.066310     0.177562      -0.013517
# Apgar5                0.107643     0.320727      -0.004932
# GA...1st.SAE          0.234001     0.700893       0.007186
# BL.Anti.inf           0.032839     0.074403       0.013873
# BL.Cortico           -0.000574     0.014132       0.033322
# BL.Antibio            0.072615     0.040325       0.035705
# BL.Bac.vag            0.014868     0.011880      -0.009700
# X..Vis.Att            1.000000     0.337906       0.709968
# X..Vis.Elig           0.337906     1.000000      -0.012611
# X1st.Miss.Vis         0.709968    -0.012611       1.000000
#
# [27 rows x 27 columns]

# %%
sns.heatmap(correlation,xticklabels=correlation.columns,
            yticklabels=correlation.columns)
# Out:
# <Axes: >

# %% [markdown]
# ## Phase 2 -
# ##           • Dimensionality reduction

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Standardizing the data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(numeric_df)

# %%
# Performing PCA
pca = PCA()
pca_result = pca.fit_transform(scaled_data)

# Print PCA results
print("Eigenvalues:", pca.explained_variance_)
print("Component Loadings:")
print(pd.DataFrame(pca.components_, columns=numeric_df.columns))
# Out:
# Eigenvalues: [6.95087319 3.35210779 2.03141036 1.82867049 1.34643674 1.33013308
#  1.22434402 1.06830012 0.98289591 0.87674819 0.8698665  0.76564016
#  0.72624588 0.65218726 0.53457812 0.44623025 0.40327615 0.33373847
#  0.30185275 0.24018225 0.23336926 0.18344983 0.14576267 0.08280941
#  0.05550351 0.04272193 0.02351243]
# Component Loadings:
#          PID       Age       BMI  N.qualifying.teeth     BL.GE   BL..BOP  \
# 26     -0.010077     0.004391    0.006298    0.000097   -0.010448   -0.018269
#
#     X..Vis.Elig  X1st.Miss.Vis
# 0      0.006508      -0.067972
# 1      0.470978       0.121771
# 2     -0.011787       0.131872
# 3     -0.080228       0.524292
# 4     -0.174558       0.106038
# 5      0.134182      -0.294437
# 6      0.001799       0.188930
# 7      0.121000      -0.258858
# 8      0.019463      -0.076729
# 9     -0.025319       0.040107
# 10    -0.004446       0.018505
# 11    -0.012942      -0.100199
# 12     0.010770      -0.133996
# 13     0.039011      -0.100155
# 14    -0.160698      -0.023010
# 15     0.010824      -0.006855
# 16     0.217549      -0.262243
# 17     0.036825      -0.047849
# 18     0.000020       0.041486
# 19    -0.277465       0.214282
# 20    -0.476169       0.211675
# 21    -0.528143      -0.510855
# 22    -0.204558      -0.116347
# 23     0.066117       0.050883
# 24     0.026207       0.021029
# 25     0.035211       0.003260
# 26     0.013082       0.011916
#
# [27 rows x 27 columns]

# %%
# Scree Plot
plt.figure(figsize=(8,5))
plt.plot(range(1, len(pca.explained_variance_)+1), pca.explained_variance_ratio_, marker='o', linestyle='--')
plt.xlabel('Number of Components')
plt.ylabel('Variance Explained')
plt.title('Scree Plot')
plt.show()

# %%
# Selectinf optimal number of components based on Scree Plot
n_comp = 2
pca_selected = PCA(n_components=n_comp)
pca_selected_result = pca_selected.fit_transform(scaled_data)

# Ploting selected PCA components
plt.figure(figsize=(8,5))
plt.scatter(pca_selected_result[:, 0], pca_selected_result[:, 1], alpha=0.5)
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.title("PCA Visualization")
plt.show()

# %%
numeric_df.head(10)
# Out:
#       PID  Age        BMI  N.qualifying.teeth  BL.GE  BL..BOP  BL.PD.avg  \
# 0  100034   25  27.669333                  13  1.429   48.214      2.696
# 1  100042   21  21.000000                  12  1.298   79.762      2.685
# 2  100067   25  24.000000                  16  1.784   80.247      2.821
# 3  100083   36  36.000000                  15  1.596  100.000      2.814
# 4  100091   21  27.000000                  16  1.173   94.048      2.768
# 5  100109   40  24.000000                  16  0.969   85.185      2.932
# 6  100117   23  32.000000                  19  1.857   92.262      2.738
# 7  100133   28  27.669333                  10  1.621   64.000      2.813
# 8  100141   25  26.000000                  21  1.981   94.444      2.994
# 9  100158   27  28.000000                  11  1.193   92.000      2.793
#
#    BL..PD.4  BL..PD.5  BL.CAL.avg  ...  Apgar1  Apgar5  GA...1st.SAE  \
# 0    17.857     5.357       1.291  ...     9.0     9.0           259
# 1    17.857    10.119       1.119  ...     4.0     7.0           259
# 2    25.309    12.346       1.407  ...     8.0     9.0           259
# 3    17.308     5.769       1.494  ...     9.0     9.0           259
# 4    23.214    14.286       1.327  ...     9.0     9.0           259
# 5    25.309    10.494       1.432  ...     8.0     9.0           259
# 6    20.833     5.357       1.292  ...     8.0     9.0           259
# 7    17.333     8.667       1.407  ...     9.0     9.0           259
# 8    29.012     7.407       1.611  ...     9.0     9.0           259
# 9    18.000     8.667       1.439  ...     9.0     9.0           150
#
#    BL.Anti.inf  BL.Cortico  BL.Antibio  BL.Bac.vag  X..Vis.Att  X..Vis.Elig  \
# 0            0           0           0           0           5            5
# 1            0           0           0           0           0            5
# 2            0           0           0           0           2            5
# 3            1           0           0           0           3            5
# 4            0           0           0           0           4            5
# 5            0           0           0           0           1            5
# 6            0           0           0           0           4            5
# 7            0           0           0           0           2            5
# 8            0           0           0           0           4            5
# 9            0           0           0           0           1            1
#
#    X1st.Miss.Vis
# 0            100
# 1              2
# 2              3
# 3              2
# 4              5
# 5              3
# 6              6
# 7              3
# 8              4
# 9            100
#
# [10 rows x 27 columns]

# %% [markdown]
# ## MODELLING

# %%
from scipy.spatial.distance import pdist, squareform
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.cluster import DBSCAN, KMeans
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

# %%
X = numeric_df.iloc[:, [3, 4]].values

# %%
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# Hierarchical clustering with dendrograms
linkage_matrix = linkage(numeric_df, method='ward')
plt.figure(figsize=(8, 5))
dendrogram(linkage_matrix)
plt.title("Dendrogram - Ward's Method")
plt.show()

# %% [markdown]
# ## Kmeans clustering

# %%
kmeans = KMeans(n_clusters = 5, init = 'k-means++', random_state = 42)
y_kmeans = kmeans.fit_predict(X)

# %%
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s = 100, c = 'blue', label = 'Cluster 2')
plt.scatter(X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], s = 100, c = 'green', label = 'Cluster 3')
plt.scatter(X[y_kmeans == 3, 0], X[y_kmeans == 3, 1], s = 100, c = 'cyan', label = 'Cluster 4')
plt.scatter(X[y_kmeans == 4, 0], X[y_kmeans == 4, 1], s = 100, c = 'magenta', label = 'Cluster 5')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clusters of patients')
plt.xlabel('Dental data')
plt.ylabel('Dentl score')
plt.legend()
plt.show()

# %% [markdown]
# ## Hierarchical Clustering

# %%
plt.figure(figsize=(8,5))
plt.title("BMI distribution",fontsize=16)
plt.xlabel ("BMI",fontsize=14)
plt.grid(True)
plt.hist(numeric_df['BMI'],color='orange',edgecolor='k')
plt.show()

# %%
import scipy.cluster.hierarchy as sch

plt.figure(figsize=(15,6))
plt.title('Dendrogram')
plt.xlabel('Customers')
plt.ylabel('Euclidean distances')
#plt.grid(True)
dendrogram = sch.dendrogram(sch.linkage(X, method = 'ward'))
plt.show()

# %%
plt.figure(figsize=(15,6))
plt.title('Dendrogram')
plt.xlabel('dental patients')
plt.ylabel('Euclidean distances')
plt.hlines(y=190,xmin=0,xmax=10000,lw=3,linestyles='--')
plt.text(x=900,y=220,s='Horizontal line crossing 5 vertical lines',fontsize=10)

dendrogram = sch.dendrogram(sch.linkage(X, method = 'ward'))
plt.show()

# %% [markdown]
# ## Evaluation of model

# %%
# Constructing a linear regression model

#plotting heatmap for overall data set
sns.heatmap(numeric_df.corr(), square=True, cmap='RdYlGn')
# Out:
# <Axes: >

# %%
#We can use the lmplot 6. method from seaborn to see the relationship between RM and MEDV. Check out the following snippet:
sns.lmplot(x = 'Age', y = 'BMI', data = numeric_df)

# %% [markdown]
# ##  linear regression model

# %%
# Preparing the data
X = df[['Age']]
y = df[['N.qualifying.teeth']]

# %%
# Splitting the dataset into train and test sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 10)

# %%
#Training a Linear Regression Model
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
# Fitting the training data to our model
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
#Model evaluation
#R^2 can be determined using our test dataset in the LinearRegression.score() method:
#check prediction score/accuracy
regressor.score(X_test, y_test)
# Out:
# 0.020986600932865307

# %%
#Before that, let's predict the y values with our model and evaluate it more. And a target variables DataFrame is also built:
# predict the y values
y_pred=regressor.predict(X_test)
# a data frame with actual and predicted values of y
evaluate = pd.DataFrame({'Actual': y_test.values.flatten(),
'Predicted': y_pred.flatten()})
evaluate.head(10)
# Out:
#    Actual  Predicted
# 0      13  14.334251
# 1      13  15.038493
# 2       7  15.038493
# 3      15  13.864757
# 4      24  13.864757
# 5      19  15.038493
# 6      11  14.451625
# 7       8  14.334251
# 8      26  14.216878
# 9      10  14.099504

# %%
evaluate.head(10).plot(kind = 'bar')
# Out:
# <Axes: >
